# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
print("images shape: %s" % str(digits.images.shape))
print("targets shape: %s" % str(digits.target.shape))
# Out:
# images shape: (1797, 8, 8)
# targets shape: (1797,)

# %%
# %pylab inline
matshow(digits.images[9], cmap=plt.cm.Greys);
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X = digits.data.reshape(-1, 64)
print X.shape
print X
# Out:
# (1797, 64)
# [[  0.   0.   5. ...,   0.   0.   0.]
#  [  0.   0.   0. ...,  10.   0.   0.]
#  [  0.   0.   0. ...,  16.   9.   0.]
#  ...,
#  [  0.   0.   1. ...,   6.   0.   0.]
#  [  0.   0.   2. ...,  12.   0.   0.]
#  [  0.   0.  10. ...,  12.   1.   0.]]

# %%
y = digits.target
print(y.shape)
# Out:
# (1797,)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
X_pca = pca.transform(X)
X_pca.shape
# Out:
# (1797, 2)

# %%
figsize(16, 10)
scatter(X_pca[:, 0], X_pca[:, 1], c=y);

# %%
print(pca.mean_.shape)
print(pca.components_.shape)
# Out:
# (64,)
# (2, 64)

# %%
fix, ax = plt.subplots(1, 3)
ax[0].matshow(pca.mean_.reshape(8, 8), cmap=plt.cm.Greys)
ax[1].matshow(pca.components_[0, :].reshape(8, 8), cmap=plt.cm.Greys)
ax[2].matshow(pca.components_[1, :].reshape(8, 8), cmap=plt.cm.Greys);

# %%
from sklearn.manifold import Isomap

# %%
isomap = Isomap(n_components=2, n_neighbors=20)

# %%
isomap.fit(X);

# %%
X_isomap = isomap.transform(X)
X_isomap.shape
# Out:
# (1797, 2)

# %%
plt.scatter(X_isomap[:, 0], X_isomap[:, 1], c=y);

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
print("X_train shape: %s" % repr(X_train.shape))
print("y_train shape: %s" % repr(y_train.shape))
print("X_test shape: %s" % repr(X_test.shape))
print("y_test shape: %s" % repr(y_test.shape))
# Out:
# X_train shape: (1347, 64)
# y_train shape: (1347,)
# X_test shape: (450, 64)
# y_test shape: (450,)

# %%
from sklearn.svm import LinearSVC

# %%
svm = LinearSVC()

# %%
svm.fit(X_train, y_train);

# %%
svm.predict(X_train)
# Out:
# array([2, 9, 9, ..., 7, 7, 8])

# %%
svm.score(X_train, y_train)
# Out:
# 0.97253155159613958

# %%
svm.score(X_test, y_test)
# Out:
# 0.91555555555555557

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0)

# %%
rf.score(X_train, y_train)
# Out:
# 0.99851521900519669

# %%
rf.score(X_test, y_test)
# Out:
# 0.9622222222222222

# %%
from sklearn.cross_validation import cross_val_score
scores =  cross_val_score(rf, X_train, y_train, cv=5)
print("scores: %s  mean: %f  std: %f" % (str(scores), np.mean(scores), np.std(scores)))
# Out:
# scores: [ 0.92592593  0.94074074  0.9330855   0.92565056  0.94423792]  mean: 0.933928  std: 0.007563

# %%
from sklearn.cross_validation import cross_val_score
scores =  cross_val_score(svm, X_train, y_train, cv=5)
print("scores: %s  mean: %f  std: %f" % (str(scores), np.mean(scores), np.std(scores)))
# Out:
# scores: [ 0.93333333  0.96296296  0.94795539  0.92936803  0.96654275]  mean: 0.948032  std: 0.015033

# %%
rf2 = RandomForestClassifier(n_estimators=50)
scores =  cross_val_score(rf2, X_train, y_train, cv=5)
print("scores: %s  mean: %f  std: %f" % (str(scores), np.mean(scores), np.std(scores)))
# Out:
# scores: [ 0.96296296  0.96666667  0.95910781  0.96282528  0.96654275]  mean: 0.963621  std: 0.002802

# %%
XX = X_train[0]
YY = y_train[0]
print XX, YY
# Out:
# [  0.   3.  13.  16.   9.   0.   0.   0.   0.  10.  15.  13.  15.   2.   0.
#    0.   0.  15.   4.   4.  16.   1.   0.   0.   0.   0.   0.   5.  16.   2.
#    0.   0.   0.   0.   1.  14.  13.   0.   0.   0.   0.   0.  10.  16.   5.
#    0.   0.   0.   0.   4.  16.  13.   8.  10.   9.   1.   0.   2.  16.  16.
#   14.  12.   9.   1.] 2

# %%
svm.predict(XX)
# Out:
# array([2])

# %%
from hcluster import pdist, linkage, dendrogram;
import numpy;
from numpy.random import rand;
dendrogram(linkage(pdist(X_train)))
# Out:
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# ...
#   '193',
#   '859',
#   '34',
#   '352',
#   '986',
#   '37',
#   '1139',
#   '1193',
#   '63',
#   '815',
#   '1102',
#   '248',
#   '98',
#   '467',
#   '1265',
#   '326',
#   '924',
#   '1077',
#   '717',
#   '159',
#   '1010',
#   '589',
#   '596',
#   '1087',
#   '1236',
#   '286',
#   '423',
#   '841',
#   '434',
#   '592',
#   '402',
#   '758',
#   '983',
#   '770',
#   '1250',
#   '1011',
#   '53',
#   '845',
#   '715',
#   '325',
#   '1051',
#   '1065',
#   '690',
#   '275',
#   '62',
#   '1148',
#   '375',
#   '1194',
#   '73',
#   '973',
#   '871',
#   '710',
#   '946',
#   '1114',
#   '663',
#   '19',
#   '1018',
#   '1180',
#   '716',
#   '3',
#   '557',
#   '789',
#   '482',
#   '1060',
#   '954',
#   '1001',
#   '544',
#   '575',
#   '1245',
#   '594',
#   '948',
#   '464',
#   '613',
#   '651',
#   '85',
#   '901',
#   '1095',
#   '1197',
#   '612',
#   '1344',
#   '528',
#   '1251',
#   '1088',
#   '998',
#   '476',
#   '1174',
#   '162',
#   '898',
#   '990',
#   '368',
#   '610',
#   '645',
#   '953',
#   '1118',
#   '1113',
#   '662',
#   '165',
#   '800',
#   '123',
#   '1243',
#   '899',
#   '732',
#   '702',
#   '1170',
#   '1223',
#   '599',
#   '890',
#   '1093',
#   '563',
#   '1238',
#   '384',
#   '414',
#   '1244',
#   '219',
#   '415',
#   '967',
#   '762',
#   '1279',
#   '768',
#   '810',
#   '418',
#   '101',
#   '972',
#   '263',
#   '1308',
#   '887',
#   '1345',
#   '650',
#   '816',
#   '137',
#   '541',
#   '1032',
#   '723',
#   '1104',
#   '1296',
#   '230',
#   '868',
#   '151',
#   '379',
#   '1043',
#   '673',
#   '865',
#   '1272',
#   '556',
#   '343',
#   '1332',
#   '1324',
#   '739',
#   '264',
#   '267',
#   '979',
#   '470',
#   '276',
#   '987',
#   '287',
#   '821',
#   '817',
#   '980',
#   '1137',
#   '683',
#   '1181',
#   '895',
#   '1105',
#   '582',
#   '1006',
#   '756',
#   '617',
#   '348',
#   '43',
#   '306',
#   '867',
#   '539',
#   '970',
#   '240',
#   '294',
#   '371',
#   '1121',
#   '910',
#   '627',
#   '509',
#   '1186',
#   '108',
#   '304',
#   '597',
#   '297',
#   '1203',
#   '195',
#   '437',
#   '1175',
#   '244',
#   '1230',
#   '805',
#   '1206',
#   '254',
#   '1064',
#   '903',
#   '472',
#   '694',
#   '892',
#   '138',
#   '1038',
#   '292',
#   '644',
#   '272',
#   '48',
#   '991',
#   '243',
#   '1057',
#   '78',
#   '1264',
#   '311',
#   '1198',
#   '737',
#   '685',
#   '261',
#   '424',
#   '104',
#   '1273',
#   '943',
#   '727',
#   '298',
#   '778',
#   '21',
#   '32',
#   '676',
#   '773',
#   '503',
#   '521',
#   '950',
#   '1117',
#   '316',
#   '753',
#   '241',
#   '259',
#   '336',
#   '858',
#   '1213',
#   '1120',
#   '61',
#   '1201',
#   '745',
#   '603',
#   '493',
#   '736',
#   '1199',
#   '385',
#   '634',
#   '919',
#   '1103',
#   '290',
#   '782',
#   '366',
#   '913',
#   '1115',
#   '1184',
#   '506',
#   '206',
#   '648',
#   '1146',
#   '362',
#   '958',
#   '279',
#   '436',
#   '1278',
#   '309',
#   '323',
#   '129',
#   '1098',
#   '624',
#   '487',
#   '452',
#   '814',
#   '18',
#   '86',
#   '412',
#   '649',
#   '199',
#   '1246',
#   '1025',
#   '546',
#   '834',
#   '722',
#   '578',
#   '413',
#   '734',
#   '692',
#   '383',
#   '707',
#   '382',
#   '227',
#   '744',
#   '278',
#   '363',
#   '823',
#   '897',
#   '358',
#   '891',
#   '1318',
#   '847',
#   '1210',
#   '488',
#   '1283',
#   '207',
#   '500',
#   '149',
#   '668',
#   '833',
#   '1269',
#   '647',
#   '687',
#   '172',
#   '389',
#   '1316',
#   '1132',
#   '1325',
#   '59',
#   '1300',
#   '314',
#   '548',
#   '1331',
#   '17',
#   '1089',
#   '1126',
#   '308',
#   '189',
#   '1019',
#   '1050',
#   '985',
#   '952',
#   '9',
#   '1188',
#   '438',
#   '88',
#   '550',
#   '4',
#   '968',
#   '1257',
#   '31',
#   '116',
#   '872',
#   '720',
#   '766',
#   '333',
#   '331',
#   '399',
#   '1222',
#   '1299',
#   '534',
#   '1149',
#   '341',
#   '759',
#   '121',
#   '667',
#   '409',
#   '1094',
#   '247',
#   '738',
#   '315',
#   '735',
#   '372',
#   '113',
#   '460',
#   '1036',
#   '1189',
#   '1160',
#   '1294',
#   '102',
#   '435',
#   '130',
#   '1179',
#   '334',
#   '631',
#   '360',
#   '208',
#   '122',
#   '1161',
#   '273',
#   '0',
#   '140',
#   '844',
#   '1195',
#   '818',
#   '718',
#   '1081',
#   '198',
#   '553',
#   '729',
#   '896',
#   '1151',
#   '660',
#   '427',
#   '512',
#   '1122',
#   '319',
#   '623',
#   '905',
#   '150',
#   '374',
#   '443',
#   '1049',
#   '840',
#   '1267',
#   '218',
#   '444',
#   '586',
#   '54',
#   '146',
#   '266',
#   '11',
#   '976',
#   '1107',
#   '1274',
#   '786',
#   '143',
#   '1085',
#   '760',
#   '1134',
#   '1234',
#   '784',
#   '1138',
#   '992',
#   '1277',
#   '926',
#   '607',
#   '106',
#   '1141',
#   '947',
#   '870',
#   '830',
#   '963',
#   '730',
#   '1262',
#   '827',
#   '674',
#   '1288',
#   '879',
#   '518',
#   '719',
#   '706',
#   '869',
#   '1233',
#   '1275',
#   '637',
#   '365',
#   '74',
#   '303',
#   '161',
#   '635',
#   '134',
#   '345',
#   '1192',
#   '380',
#   '777',
#   '1009',
#   '103',
#   '579',
#   '251',
#   '1284',
#   '642',
#   '618',
#   '7',
#   '616',
#   '136',
#   '1068',
#   '966',
#   '775',
#   '1334',
#   '1164',
#   '82',
#   '632',
#   '684',
#   '8',
#   '91',
#   '1158',
#   '40',
#   '697',
#   '1008',
#   '1183',
#   '90',
#   '428',
#   '959',
#   '483',
#   '714',
#   '346',
#   '888',
#   '693',
#   '211',
#   '1266',
#   '205',
#   '398',
#   '139',
#   '1268',
#   '502',
#   '587',
#   '681',
#   '318',
#   '1128',
#   '451',
#   '1217',
#   '72',
#   '620',
#   '1071',
#   '1196',
#   '50',
#   '215',
#   '245',
#   '567',
#   '783',
#   '184',
#   '342',
#   '1260',
#   '232',
#   '881',
#   '1256',
#   '933',
#   '527',
#   '1099',
#   '964',
#   '367',
#   '1301',
#   '831',
#   '440',
#   '89',
#   '474',
#   '60',
#   '317',
#   '350',
#   '52',
#   '128',
#   '209',
#   '813',
#   '559',
#   '799',
#   '1177',
#   '301',
#   '69',
#   '353',
#   '1204',
#   '112',
#   '212',
#   '1239',
#   '1215',
#   '242',
#   '373',
#   '485',
#   '508',
#   '157',
#   '167',
#   '448',
#   '747',
#   '132',
#   '15',
#   '1026',
#   '446',
#   '571',
#   '322',
#   '45',
#   '547',
#   '1326',
#   '1303',
#   '519',
#   '698',
#   '978',
#   '1330',
#   '131',
#   '370',
#   '498',
#   '1202',
#   '270',
#   '1187',
#   '797',
#   '853',
#   '442',
#   '124',
#   '700',
#   '430',
#   '237',
#   '595',
#   '1075',
#   '657',
#   '174',
#   '12',
#   '1315',
#   '1224',
#   '381',
#   '932',
#   '507',
#   '842',
#   '204',
#   '288',
#   '561',
#   '456',
#   '741',
#   '329',
#   '68',
#   '224',
#   '984',
#   '1310',
#   '1015',
#   '235',
#   '148',
#   '1143',
#   '178',
#   '846',
#   '653',
#   '935',
#   '885',
#   '361',
#   '239',
#   '411',
#   '168',
#   '253',
#   '265',
#   '1046',
#   '1221',
#   '258',
#   '1242',
#   '351',
#   '525',
#   '1029',
#   '164',
#   '260',
#   '686',
#   '1225',
#   '787',
#   '236',
#   '746',
#   '94',
#   '171',
#   '1341',
#   '1314',
#   '42',
#   '473',
#   '802',
#   '576',
#   '1302',
#   '390',
#   '552',
#   '749',
#   '305',
#   '688',
#   '957',
#   '1229',
#   '403',
#   '422',
#   '875',
#   '549',
#   '13',
#   '733',
#   '1052',
#   '639',
#   '256',
#   '481',
#   '97',
#   '225',
#   '457',
#   '1147',
#   '1076',
#   '1322',
#   '1013',
#   '523',
#   '1154',
#   '221',
#   '703',
#   '1163',
#   '217',
#   '848',
#   '918',
#   '1086',
#   '135',
#   '1084',
#   '190',
#   '809',
#   '1319',
#   '931',
#   '188',
#   '447',
#   '779',
#   '850',
#   '1129',
#   '56',
#   '664',
#   '955',
#   '125',
#   '1145',
#   '1155',
#   '1235',
#   '77',
#   '445',
#   '81',
#   '479',
#   '795',
#   '581',
#   '2',
#   '192',
#   '1063',
#   '828',
#   '220',
#   '274',
#   '499',
#   '661',
#   '988',
#   '1070',
#   '295',
#   '1034',
#   '327',
#   '1142',
#   '1248',
#   '1285',
#   '369',
#   '393',
#   '658',
#   '625',
#   '1090',
#   '431',
#   '731',
#   '238',
#   '593',
#   '173',
#   '169',
#   '1343',
#   '307',
#   '638',
#   '355',
#   '999',
#   '47',
#   '1214',
#   '863',
#   '621',
#   '419',
#   '942',
#   '1130',
#   '1136',
#   '196',
#   '1311',
#   '163',
#   '960',
#   '320',
#   '825',
#   '1253',
#   '772',
#   '911',
#   '1305',
#   '313',
#   '974',
#   '344',
#   '1055',
#   '601',
#   '608',
#   '349',
#   '876',
#   '296',
#   '843',
#   '937',
#   '857',
#   '1342',
#   '433',
#   '516',
#   '965',
#   '611',
#   '1131',
#   '387',
#   '530',
#   '397',
#   '628',
#   '1156',
#   '376',
#   '1092',
#   '696',
#   '997',
#   '529',
#   '1078',
#   '29',
#   '884',
#   '1259',
#   '302',
#   '995',
#   '540',
#   '490',
#   '572',
#   '554',
#   '671',
#   '214',
#   '1023',
#   '1072',
#   '429',
#   '820',
#   '271',
#   '654',
#   '878',
#   '615',
#   '312',
#   '283',
#   '339',
#   '761',
#   '1116',
#   '183',
#   '748',
#   '1328',
#   '511',
#   '197',
#   '477',
#   '1211',
#   '36',
#   '156',
#   '462',
#   '1323',
#   '1027',
#   '1091',
#   '570',
#   '1231',
#   '883',
#   '1263',
#   '67',
#   '573',
#   '862',
#   '252',
#   '1178',
#   '105',
#   '1329',
#   '752',
#   '794',
#   '1004',
#   '606',
#   '404',
#   '14',
#   '22',
#   '158',
#   '1074',
#   '1208',
#   '388',
#   '27',
#   '677',
#   '1150',
#   '1200',
#   '1020',
#   '742',
#   '837',
#   '856',
#   '909',
#   '641',
#   '269',
#   '914',
#   '87',
#   '1153',
#   '640',
#   '1168',
#   '754',
#   '695',
#   '993',
#   '83',
#   '763',
#   '109',
#   '874',
#   '92',
#   '543',
#   '669',
#   '1040',
#   '299',
#   '704',
#   '1045',
#   '929',
#   '340',
#   '835',
#   '111',
#   '562',
#   '750',
#   '1100',
#   '1111',
#   '1289',
#   '824',
#   '1003',
#   '860',
#   '1061',
#   '405',
#   '505',
#   '1056',
#   '1216',
#   '1313',
#   '1321',
#   '250',
#   '280',
#   '679',
#   '1066',
#   '785',
#   '535',
#   '377',
#   '849',
#   '930',
#   '680',
#   '465',
#   '725',
#   '432',
#   '201',
#   '922',
#   '1261',
#   '1286',
#   '1000',
#   '1039',
#   '119',
#   '177',
#   '46',
#   '1166',
#   '1270',
#   '80',
#   '1159',
#   '200',
#   '1108',
#   '515',
#   '486',
#   '471',
#   '560',
#   '461',
#   '1135',
#   '133',
#   '803',
#   '10',
#   '1333',
#   '335',
#   '210',
#   '522',
#   '321',
#   '1007',
#   '609',
#   '1327',
#   '49',
#   '406',
#   '889',
#   '1109',
#   '1209',
#   '115',
#   '659',
#   '781',
#   '1101',
#   '234',
#   '962',
#   '626',
#   '395',
#   '1062',
#   '491',
#   '788',
#   '1021',
#   '203',
#   '468',
#   '709',
#   '1047',
#   '182',
#   '154',
#   '324',
#   '864',
#   '774',
#   '796',
#   '906',
#   '495',
#   '1291',
#   '558',
#   '1280',
#   ...],
#  'leaves': [721,
#   941,
#   127,
#   790,
#   426,
#   1282,
#   602,
#   408,
#   902,
#   1127,
#   1002,
#   1097,
#   904,
#   1249,
#   1320,
#   95,
#   836,
#   107,
#   982,
#   257,
#   110,
#   223,
#   996,
#   93,
#   893,
#   152,
#   392,
#   956,
#   689,
#   1185,
#   246,
#   1258,
#   497,
#   832,
#   57,
#   514,
#   588,
#   665,
#   711,
#   938,
#   1190,
#   1033,
#   822,
#   193,
#   859,
#   34,
#   352,
#   986,
#   37,
#   1139,
#   1193,
#   63,
#   815,
#   1102,
#   248,
#   98,
#   467,
#   1265,
#   326,
#   924,
#   1077,
#   717,
#   159,
#   1010,
#   589,
#   596,
#   1087,
#   1236,
#   286,
#   423,
#   841,
#   434,
#   592,
#   402,
#   758,
#   983,
#   770,
#   1250,
#   1011,
#   53,
#   845,
#   715,
#   325,
#   1051,
#   1065,
#   690,
#   275,
#   62,
#   1148,
#   375,
#   1194,
#   73,
#   973,
#   871,
#   710,
#   946,
#   1114,
#   663,
#   19,
#   1018,
#   1180,
#   716,
#   3,
#   557,
#   789,
#   482,
#   1060,
#   954,
#   1001,
#   544,
#   575,
#   1245,
#   594,
#   948,
#   464,
#   613,
#   651,
#   85,
#   901,
#   1095,
#   1197,
#   612,
#   1344,
#   528,
#   1251,
#   1088,
#   998,
#   476,
#   1174,
#   162,
#   898,
#   990,
#   368,
#   610,
#   645,
#   953,
#   1118,
#   1113,
#   662,
#   165,
#   800,
#   123,
#   1243,
#   899,
#   732,
#   702,
#   1170,
#   1223,
#   599,
#   890,
#   1093,
#   563,
#   1238,
#   384,
#   414,
#   1244,
#   219,
#   415,
#   967,
#   762,
#   1279,
#   768,
#   810,
#   418,
#   101,
#   972,
#   263,
#   1308,
#   887,
#   1345,
#   650,
#   816,
#   137,
#   541,
#   1032,
#   723,
#   1104,
#   1296,
#   230,
#   868,
#   151,
#   379,
#   1043,
#   673,
#   865,
#   1272,
#   556,
#   343,
#   1332,
#   1324,
#   739,
#   264,
#   267,
#   979,
#   470,
#   276,
#   987,
#   287,
#   821,
#   817,
#   980,
#   1137,
#   683,
#   1181,
#   895,
#   1105,
#   582,
#   1006,
#   756,
#   617,
#   348,
#   43,
#   306,
#   867,
#   539,
#   970,
#   240,
#   294,
#   371,
#   1121,
#   910,
#   627,
#   509,
#   1186,
#   108,
#   304,
#   597,
#   297,
#   1203,
#   195,
#   437,
#   1175,
#   244,
#   1230,
#   805,
#   1206,
#   254,
#   1064,
#   903,
#   472,
#   694,
#   892,
#   138,
#   1038,
#   292,
#   644,
#   272,
#   48,
#   991,
#   243,
#   1057,
#   78,
#   1264,
#   311,
#   1198,
#   737,
#   685,
#   261,
#   424,
#   104,
#   1273,
#   943,
#   727,
#   298,
#   778,
#   21,
#   32,
#   676,
#   773,
#   503,
#   521,
#   950,
#   1117,
#   316,
#   753,
#   241,
#   259,
#   336,
#   858,
#   1213,
#   1120,
#   61,
#   1201,
#   745,
#   603,
#   493,
#   736,
#   1199,
#   385,
#   634,
#   919,
#   1103,
#   290,
#   782,
#   366,
#   913,
#   1115,
#   1184,
#   506,
#   206,
#   648,
#   1146,
#   362,
#   958,
#   279,
#   436,
#   1278,
#   309,
#   323,
#   129,
#   1098,
#   624,
#   487,
#   452,
#   814,
#   18,
#   86,
#   412,
#   649,
#   199,
#   1246,
#   1025,
#   546,
#   834,
#   722,
#   578,
#   413,
#   734,
#   692,
#   383,
#   707,
#   382,
#   227,
#   744,
#   278,
#   363,
#   823,
#   897,
#   358,
#   891,
#   1318,
#   847,
#   1210,
#   488,
#   1283,
#   207,
#   500,
#   149,
#   668,
#   833,
#   1269,
#   647,
#   687,
#   172,
#   389,
#   1316,
#   1132,
#   1325,
#   59,
#   1300,
#   314,
#   548,
#   1331,
#   17,
#   1089,
#   1126,
#   308,
#   189,
#   1019,
#   1050,
#   985,
#   952,
#   9,
#   1188,
#   438,
#   88,
#   550,
#   4,
#   968,
#   1257,
#   31,
#   116,
#   872,
#   720,
#   766,
#   333,
#   331,
#   399,
#   1222,
#   1299,
#   534,
#   1149,
#   341,
#   759,
#   121,
#   667,
#   409,
#   1094,
#   247,
#   738,
#   315,
#   735,
#   372,
#   113,
#   460,
#   1036,
#   1189,
#   1160,
#   1294,
#   102,
#   435,
#   130,
#   1179,
#   334,
#   631,
#   360,
#   208,
#   122,
#   1161,
#   273,
#   0,
#   140,
#   844,
#   1195,
#   818,
#   718,
#   1081,
#   198,
#   553,
#   729,
#   896,
#   1151,
#   660,
#   427,
#   512,
#   1122,
#   319,
#   623,
#   905,
#   150,
#   374,
#   443,
#   1049,
#   840,
#   1267,
#   218,
#   444,
#   586,
#   54,
#   146,
#   266,
#   11,
#   976,
#   1107,
#   1274,
#   786,
#   143,
#   1085,
#   760,
#   1134,
#   1234,
#   784,
#   1138,
#   992,
#   1277,
#   926,
#   607,
#   106,
#   1141,
#   947,
#   870,
#   830,
#   963,
#   730,
#   1262,
#   827,
#   674,
#   1288,
#   879,
#   518,
#   719,
#   706,
#   869,
#   1233,
#   1275,
#   637,
#   365,
#   74,
#   303,
#   161,
#   635,
#   134,
#   345,
#   1192,
#   380,
#   777,
#   1009,
#   103,
#   579,
#   251,
#   1284,
#   642,
#   618,
#   7,
#   616,
#   136,
#   1068,
#   966,
#   775,
#   1334,
#   1164,
#   82,
#   632,
#   684,
#   8,
#   91,
#   1158,
#   40,
#   697,
#   1008,
#   1183,
#   90,
#   428,
#   959,
#   483,
#   714,
#   346,
#   888,
#   693,
#   211,
#   1266,
#   205,
#   398,
#   139,
#   1268,
#   502,
#   587,
#   681,
#   318,
#   1128,
#   451,
#   1217,
#   72,
#   620,
#   1071,
#   1196,
#   50,
#   215,
#   245,
#   567,
#   783,
#   184,
#   342,
#   1260,
#   232,
#   881,
#   1256,
#   933,
#   527,
#   1099,
#   964,
#   367,
#   1301,
#   831,
#   440,
#   89,
#   474,
#   60,
#   317,
#   350,
#   52,
#   128,
#   209,
#   813,
#   559,
#   799,
#   1177,
#   301,
#   69,
#   353,
#   1204,
#   112,
#   212,
#   1239,
#   1215,
#   242,
#   373,
#   485,
#   508,
#   157,
#   167,
#   448,
#   747,
#   132,
#   15,
#   1026,
#   446,
#   571,
#   322,
#   45,
#   547,
#   1326,
#   1303,
#   519,
#   698,
#   978,
#   1330,
#   131,
#   370,
#   498,
#   1202,
#   270,
#   1187,
#   797,
#   853,
#   442,
#   124,
#   700,
#   430,
#   237,
#   595,
#   1075,
#   657,
#   174,
#   12,
#   1315,
#   1224,
#   381,
#   932,
#   507,
#   842,
#   204,
#   288,
#   561,
#   456,
#   741,
#   329,
#   68,
#   224,
#   984,
#   1310,
#   1015,
#   235,
#   148,
#   1143,
#   178,
#   846,
#   653,
#   935,
#   885,
#   361,
#   239,
#   411,
#   168,
#   253,
#   265,
#   1046,
#   1221,
#   258,
#   1242,
#   351,
#   525,
#   1029,
#   164,
#   260,
#   686,
#   1225,
#   787,
#   236,
#   746,
#   94,
#   171,
#   1341,
#   1314,
#   42,
#   473,
#   802,
#   576,
#   1302,
#   390,
#   552,
#   749,
#   305,
#   688,
#   957,
#   1229,
#   403,
#   422,
#   875,
#   549,
#   13,
#   733,
#   1052,
#   639,
#   256,
#   481,
#   97,
#   225,
#   457,
#   1147,
#   1076,
#   1322,
#   1013,
#   523,
#   1154,
#   221,
#   703,
#   1163,
#   217,
#   848,
#   918,
#   1086,
#   135,
#   1084,
#   190,
#   809,
#   1319,
#   931,
#   188,
#   447,
#   779,
#   850,
#   1129,
#   56,
#   664,
#   955,
#   125,
#   1145,
#   1155,
#   1235,
#   77,
#   445,
#   81,
#   479,
#   795,
#   581,
#   2,
#   192,
#   1063,
#   828,
#   220,
#   274,
#   499,
#   661,
#   988,
#   1070,
#   295,
#   1034,
#   327,
#   1142,
#   1248,
#   1285,
#   369,
#   393,
#   658,
#   625,
#   1090,
#   431,
#   731,
#   238,
#   593,
#   173,
#   169,
#   1343,
#   307,
#   638,
#   355,
#   999,
#   47,
#   1214,
#   863,
#   621,
#   419,
#   942,
#   1130,
#   1136,
#   196,
#   1311,
#   163,
#   960,
#   320,
#   825,
#   1253,
#   772,
#   911,
#   1305,
#   313,
#   974,
#   344,
#   1055,
#   601,
#   608,
#   349,
#   876,
#   296,
#   843,
#   937,
#   857,
#   1342,
#   433,
#   516,
#   965,
#   611,
#   1131,
#   387,
#   530,
#   397,
#   628,
#   1156,
#   376,
#   1092,
#   696,
#   997,
#   529,
#   1078,
#   29,
#   884,
#   1259,
#   302,
#   995,
#   540,
#   490,
#   572,
#   554,
#   671,
#   214,
#   1023,
#   1072,
#   429,
#   820,
#   271,
#   654,
#   878,
#   615,
#   312,
#   283,
#   339,
#   761,
#   1116,
#   183,
#   748,
#   1328,
#   511,
#   197,
#   477,
#   1211,
#   36,
#   156,
#   462,
#   1323,
#   1027,
#   1091,
#   570,
#   1231,
#   883,
#   1263,
#   67,
#   573,
#   862,
#   252,
#   1178,
#   105,
#   1329,
#   752,
#   794,
#   1004,
#   606,
#   404,
#   14,
#   22,
#   158,
#   1074,
#   1208,
#   388,
#   27,
#   677,
#   1150,
#   1200,
#   1020,
#   742,
#   837,
#   856,
#   909,
#   641,
#   269,
#   914,
#   87,
#   1153,
#   640,
#   1168,
#   754,
#   695,
#   993,
#   83,
#   763,
#   109,
#   874,
#   92,
#   543,
#   669,
#   1040,
#   299,
#   704,
#   1045,
#   929,
#   340,
#   835,
#   111,
#   562,
#   750,
#   1100,
#   1111,
#   1289,
#   824,
#   1003,
#   860,
#   1061,
#   405,
#   505,
#   1056,
#   1216,
#   1313,
#   1321,
#   250,
#   280,
#   679,
#   1066,
#   785,
#   535,
#   377,
#   849,
#   930,
#   680,
#   465,
#   725,
#   432,
#   201,
#   922,
#   1261,
#   1286,
#   1000,
#   1039,
#   119,
#   177,
#   46,
#   1166,
#   1270,
#   80,
#   1159,
#   200,
#   1108,
#   515,
#   486,
#   471,
#   560,
#   461,
#   1135,
#   133,
#   803,
#   10,
#   1333,
#   335,
#   210,
#   522,
#   321,
#   1007,
#   609,
#   1327,
#   49,
#   406,
#   889,
#   1109,
#   1209,
#   115,
#   659,
#   781,
#   1101,
#   234,
#   962,
#   626,
#   395,
#   1062,
#   491,
#   788,
#   1021,
#   203,
#   468,
#   709,
#   1047,
#   182,
#   154,
#   324,
#   864,
#   774,
#   796,
#   906,
#   495,
#   1291,
#   558,
#   1280,
#   ...]}

# %%
dendrogram(linkage(pdist(X_test)))
# Out:
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2313: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   h = Z[i-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2284: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uan = Z[ua-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2289: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubd = Z[ub-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2290: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ubn = Z[ub-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2215: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   aa = Z[i-n, 0]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2216: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   ab = Z[i-n, 1]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2219: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   na = Z[aa-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2221: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   da = Z[aa-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2226: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   nb = Z[ab-n, 3]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2227: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   db = Z[ab-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:2283: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   uad = Z[ua-n, 2]
# /Users/tobie/anaconda/lib/python2.7/site-packages/hcluster/hierarchy.py:
#   '3',
#   '67',
#   '144',
#   '334',
#   '41',
#   '139',
#   '306',
#   '386',
#   '233',
#   '404',
#   '323',
#   '58',
#   '198',
#   '390',
#   '162',
#   '371',
#   '4',
#   '32',
#   '342',
#   '262',
#   '15',
#   '439',
#   '13',
#   '182',
#   '230',
#   '239',
#   '178',
#   '127',
#   '154',
#   '225',
#   '281',
#   '290',
#   '331',
#   '124',
#   '330',
#   '24',
#   '46',
#   '106',
#   '21',
#   '302',
#   '389',
#   '388',
#   '409',
#   '321',
#   '94',
#   '52',
#   '238',
#   '179',
#   '190',
#   '368',
#   '337',
#   '350',
#   '397',
#   '125',
#   '445',
#   '161',
#   '137',
#   '255',
#   '410',
#   '192',
#   '195',
#   '79',
#   '31',
#   '43',
#   '86',
#   '282',
#   '249',
#   '422',
#   '159',
#   '114',
#   '265',
#   '243',
#   '311',
#   '95',
#   '42',
#   '245',
#   '253',
#   '5',
#   '224',
#   '258',
#   '425',
#   '214',
#   '108',
#   '280',
#   '289',
#   '315',
#   '319',
#   '23',
#   '173',
#   '123',
#   '180',
#   '296',
#   '347',
#   '272',
#   '26',
#   '432',
#   '63',
#   '393',
#   '363',
#   '364',
#   '394',
#   '199',
#   '308',
#   '203',
#   '294',
#   '356',
#   '30',
#   '111',
#   '266',
#   '365',
#   '35',
#   '221',
#   '96',
#   '292',
#   '259',
#   '184',
#   '423',
#   '172',
#   '354',
#   '307',
#   '269',
#   '392',
#   '105',
#   '126',
#   '188',
#   '351',
#   '165',
#   '208',
#   '60',
#   '310',
#   '45',
#   '300',
#   '376',
#   '424',
#   '38',
#   '387',
#   '369',
#   '17',
#   '426',
#   '55',
#   '304',
#   '345',
#   '83',
#   '383',
#   '194',
#   '328',
#   '54',
#   '412',
#   '237',
#   '201',
#   '384',
#   '215',
#   '443',
#   '130',
#   '378',
#   '357',
#   '433',
#   '20',
#   '61',
#   '415',
#   '226',
#   '275',
#   '117',
#   '212',
#   '235',
#   '391',
#   '48',
#   '74',
#   '284',
#   '374',
#   '220',
#   '120',
#   '140',
#   '338',
#   '251',
#   '309',
#   '440',
#   '395',
#   '102',
#   '405',
#   '28',
#   '76',
#   '89',
#   '10',
#   '2',
#   '254',
#   '288',
#   '303',
#   '80',
#   '298',
#   '317',
#   '336',
#   '0',
#   '236',
#   '322',
#   '406',
#   '77',
#   '244',
#   '122',
#   '437',
#   '90',
#   '44',
#   '372',
#   '268',
#   '1',
#   '97',
#   '326',
#   '163',
#   '263',
#   '211',
#   '305',
#   '358',
#   '367',
#   '213',
#   '446',
#   '99',
#   '158',
#   '6',
#   '411',
#   '200',
#   '301',
#   '104',
#   '218',
#   '75',
#   '277',
#   '293',
#   '333',
#   '355',
#   '152',
#   '56',
#   '100',
#   '87',
#   '146',
#   '286',
#   '136',
#   '283',
#   '9',
#   '72',
#   '129',
#   '373',
#   '257',
#   '417',
#   '18',
#   '148',
#   '250',
#   '428',
#   '248',
#   '25',
#   '98',
#   '133',
#   '247',
#   '103',
#   '314',
#   '84',
#   '101',
#   '210',
#   '340',
#   '344',
#   '418',
#   '191',
#   '256',
#   '119',
#   '361',
#   '121',
#   '138',
#   '403',
#   '447',
#   '274',
#   '362',
#   '19',
#   '169',
#   '400',
#   '40',
#   '112',
#   '141',
#   '318',
#   '177',
#   '402',
#   '316',
#   '377',
#   '8',
#   '22',
#   '332',
#   '252',
#   '68',
#   '382',
#   '299',
#   '7',
#   '150',
#   '231',
#   '181',
#   '62',
#   '207',
#   '185',
#   '430',
#   '291',
#   '131',
#   '132',
#   '260',
#   '135',
#   '134',
#   '242',
#   '168',
#   '346',
#   '353',
#   '65',
#   '113',
#   '209',
#   '399',
#   '29',
#   '27',
#   '50',
#   '149',
#   '78',
#   '197',
#   '419',
#   '449',
#   '34',
#   '219',
#   '85',
#   '320',
#   '379',
#   '267',
#   '110',
#   '295',
#   '59',
#   '153',
#   '206',
#   '407',
#   '438',
#   '413',
#   '186',
#   '421',
#   '71',
#   '234',
#   '183',
#   '232',
#   '375',
#   '431',
#   '176',
#   '414',
#   '36',
#   '396',
#   '287',
#   '381',
#   '223',
#   '187',
#   '270',
#   '92',
#   '228',
#   '81',
#   '227',
#   '222',
#   '53',
#   '436',
#   '264',
#   '429',
#   '166',
#   '33',
#   '246',
#   '49',
#   '88',
#   '325',
#   '348',
#   '434',
#   '39',
#   '145',
#   '240',
#   '216',
#   '73',
#   '151',
#   '93',
#   '16',
#   '444',
#   '366',
#   '335',
#   '196',
#   '398',
#   '278',
#   '155',
#   '37',
#   '229',
#   '448',
#   '57',
#   '408',
#   '420',
#   '241',
#   '147',
#   '441',
#   '69',
#   '128',
#   '202',
#   '435',
#   '193',
#   '313',
#   '167',
#   '352',
#   '116',
#   '11',
#   '279',
#   '70',
#   '329',
#   '171',
#   '380',
#   '312',
#   '115',
#   '324'],
#  'leaves': [66,
#   143,
#   427,
#   118,
#   157,
#   91,
#   370,
#   109,
#   156,
#   359,
#   285,
#   385,
#   205,
#   343,
#   189,
#   273,
#   339,
#   107,
#   327,
#   64,
#   174,
#   341,
#   261,
#   349,
#   416,
#   142,
#   164,
#   217,
#   297,
#   271,
#   204,
#   51,
#   12,
#   442,
#   276,
#   401,
#   170,
#   82,
#   14,
#   160,
#   360,
#   47,
#   175,
#   3,
#   67,
#   144,
#   334,
#   41,
#   139,
#   306,
#   386,
#   233,
#   404,
#   323,
#   58,
#   198,
#   390,
#   162,
#   371,
#   4,
#   32,
#   342,
#   262,
#   15,
#   439,
#   13,
#   182,
#   230,
#   239,
#   178,
#   127,
#   154,
#   225,
#   281,
#   290,
#   331,
#   124,
#   330,
#   24,
#   46,
#   106,
#   21,
#   302,
#   389,
#   388,
#   409,
#   321,
#   94,
#   52,
#   238,
#   179,
#   190,
#   368,
#   337,
#   350,
#   397,
#   125,
#   445,
#   161,
#   137,
#   255,
#   410,
#   192,
#   195,
#   79,
#   31,
#   43,
#   86,
#   282,
#   249,
#   422,
#   159,
#   114,
#   265,
#   243,
#   311,
#   95,
#   42,
#   245,
#   253,
#   5,
#   224,
#   258,
#   425,
#   214,
#   108,
#   280,
#   289,
#   315,
#   319,
#   23,
#   173,
#   123,
#   180,
#   296,
#   347,
#   272,
#   26,
#   432,
#   63,
#   393,
#   363,
#   364,
#   394,
#   199,
#   308,
#   203,
#   294,
#   356,
#   30,
#   111,
#   266,
#   365,
#   35,
#   221,
#   96,
#   292,
#   259,
#   184,
#   423,
#   172,
#   354,
#   307,
#   269,
#   392,
#   105,
#   126,
#   188,
#   351,
#   165,
#   208,
#   60,
#   310,
#   45,
#   300,
#   376,
#   424,
#   38,
#   387,
#   369,
#   17,
#   426,
#   55,
#   304,
#   345,
#   83,
#   383,
#   194,
#   328,
#   54,
#   412,
#   237,
#   201,
#   384,
#   215,
#   443,
#   130,
#   378,
#   357,
#   433,
#   20,
#   61,
#   415,
#   226,
#   275,
#   117,
#   212,
#   235,
#   391,
#   48,
#   74,
#   284,
#   374,
#   220,
#   120,
#   140,
#   338,
#   251,
#   309,
#   440,
#   395,
#   102,
#   405,
#   28,
#   76,
#   89,
#   10,
#   2,
#   254,
#   288,
#   303,
#   80,
#   298,
#   317,
#   336,
#   0,
#   236,
#   322,
#   406,
#   77,
#   244,
#   122,
#   437,
#   90,
#   44,
#   372,
#   268,
#   1,
#   97,
#   326,
#   163,
#   263,
#   211,
#   305,
#   358,
#   367,
#   213,
#   446,
#   99,
#   158,
#   6,
#   411,
#   200,
#   301,
#   104,
#   218,
#   75,
#   277,
#   293,
#   333,
#   355,
#   152,
#   56,
#   100,
#   87,
#   146,
#   286,
#   136,
#   283,
#   9,
#   72,
#   129,
#   373,
#   257,
#   417,
#   18,
#   148,
#   250,
#   428,
#   248,
#   25,
#   98,
#   133,
#   247,
#   103,
#   314,
#   84,
#   101,
#   210,
#   340,
#   344,
#   418,
#   191,
#   256,
#   119,
#   361,
#   121,
#   138,
#   403,
#   447,
#   274,
#   362,
#   19,
#   169,
#   400,
#   40,
#   112,
#   141,
#   318,
#   177,
#   402,
#   316,
#   377,
#   8,
#   22,
#   332,
#   252,
#   68,
#   382,
#   299,
#   7,
#   150,
#   231,
#   181,
#   62,
#   207,
#   185,
#   430,
#   291,
#   131,
#   132,
#   260,
#   135,
#   134,
#   242,
#   168,
#   346,
#   353,
#   65,
#   113,
#   209,
#   399,
#   29,
#   27,
#   50,
#   149,
#   78,
#   197,
#   419,
#   449,
#   34,
#   219,
#   85,
#   320,
#   379,
#   267,
#   110,
#   295,
#   59,
#   153,
#   206,
#   407,
#   438,
#   413,
#   186,
#   421,
#   71,
#   234,
#   183,
#   232,
#   375,
#   431,
#   176,
#   414,
#   36,
#   396,
#   287,
#   381,
#   223,
#   187,
#   270,
#   92,
#   228,
#   81,
#   227,
#   222,
#   53,
#   436,
#   264,
#   429,
#   166,
#   33,
#   246,
#   49,
#   88,
#   325,
#   348,
#   434,
#   39,
#   145,
#   240,
#   216,
#   73,
#   151,
#   93,
#   16,
#   444,
#   366,
#   335,
#   196,
#   398,
#   278,
#   155,
#   37,
#   229,
#   448,
#   57,
#   408,
#   420,
#   241,
#   147,
#   441,
#   69,
#   128,
#   202,
#   435,
#   193,
#   313,
#   167,
#   352,
#   116,
#   11,
#   279,
#   70,
#   329,
#   171,
#   380,
#   312,
#   115,
#   324]}
